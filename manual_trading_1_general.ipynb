# %%
from sympy import lambdify
from sympy import symbols, integrate, solve
from scipy.optimize import minimize_scalar
import numpy as np
import matplotlib.pyplot as plt


# Define the range of prices from 900 to 1000
prices = np.linspace(900, 1000, 101)

# Calculate the probability for each price using the linear probability distribution
# Since k = 1/5000 and probability scales linearly from least likely at 900 to most likely at 1000
probabilityBidEqualsAsk = (prices - 900) * (1/5000)

# Calculate the probability for each price using the linear probability distribution
# Since k = 1/5000 and probability scales linearly from least likely at 900 to most likely at 1000
probabilityBidGreaterThanAsk = ((prices ** 2)/10000) - ((9 * prices)/50) + 81
probabilityBidIsLessThanAsk = 1 - probabilityBidGreaterThanAsk

# Calculate the payoff for each bid in the range
payoff = (1000 - prices) * probabilityBidGreaterThanAsk

pricesOfPayoff = dict(zip(prices, payoff)) 
maxPriceBid = max(pricesOfPayoff, key=pricesOfPayoff.get)
maxPayoff = max(payoff)

firstBid = int(maxPriceBid)
firstBidIndex = int(firstBid - 900)

firstBids = []
maxPayoffs = []

for firstBid in range(900, 1000):
    firstBids.append(firstBid)
    firstBidIndex = int(firstBid - 900)

    probabilitySecondBidEqualsAsk = probabilityBidEqualsAsk[firstBidIndex:] / probabilityBidIsLessThanAsk[firstBidIndex]

    # Define the prices
    newPrices = np.linspace(firstBid, 1000, 1000 - firstBid + 1)

    newCumulativeProbability = ((newPrices ** 2)/(2*probabilityBidIsLessThanAsk[firstBidIndex]*5000)) - ((900 * newPrices)/(5000 * probabilityBidIsLessThanAsk[firstBidIndex]))
    newCumulativeProbability -= newCumulativeProbability[0]

    # Calculate the payoff for each bid in the range
    newPayoff = (1000 - newPrices) * newCumulativeProbability * probabilityBidIsLessThanAsk[firstBidIndex]

    pricesOfNewPayoff = dict(zip(newPrices, newPayoff)) 
    maxSecondPayoff = max(newPayoff)
    maxSecondPayoffBid = max(pricesOfNewPayoff, key=pricesOfNewPayoff.get)

    secondBid = int(maxSecondPayoffBid)
    secondBidIndex = int(secondBid - 900 - firstBidIndex)

    totalPayoff = (payoff[firstBidIndex] + newPayoff[secondBidIndex])
    print(f"First bid: {firstBid}, second bid: {secondBid}, pFirstBid: {probabilityBidGreaterThanAsk[firstBidIndex]}, pSecondBid: {newCumulativeProbability[secondBidIndex]}, firstBidPayoff: {payoff[firstBidIndex]}, secondBidPayoff: {newPayoff[secondBidIndex]}, totalPayoff: {totalPayoff}\n")
# Out:
# First bid: 900, second bid: 967, pFirstBid: 0.0, pSecondBid: 0.44889999999999475, firstBidPayoff: 0.0, secondBidPayoff: 14.813699999999827, totalPayoff: 14.813699999999827
#
# First bid: 901, second bid: 967, pFirstBid: 9.99999999891088e-05, pSecondBid: 0.4488448844884516, firstBidPayoff: 0.009899999998921771, secondBidPayoff: 14.810400000000252, totalPayoff: 14.820299999999174
#
# First bid: 902, second bid: 967, pFirstBid: 0.0003999999999848569, pSecondBid: 0.44867947178870793, firstBidPayoff: 0.03919999999851598, secondBidPayoff: 14.800499999999975, totalPayoff: 14.83969999999849
#
# First bid: 903, second bid: 967, pFirstBid: 0.0009000000000014552, pSecondBid: 0.44840356320689523, firstBidPayoff: 0.08730000000014115, secondBidPayoff: 14.784000000000276, totalPayoff: 14.871300000000417
#
# First bid: 904, second bid: 967, pFirstBid: 0.001599999999996271, pSecondBid: 0.4480168269230802, firstBidPayoff: 0.15359999999964202, secondBidPayoff: 14.760900000000163, totalPayoff: 14.914499999999805
#
# First bid: 905, second bid: 967, pFirstBid: 0.0024999999999977263, pSecondBid: 0.4475187969924548, firstBidPayoff: 0.237499999999784, secondBidPayoff: 14.731199999999165, totalPayoff: 14.968699999998949
#
# First bid: 906, second bid: 967, pFirstBid: 0.00359999999999161, pSecondBid: 0.4469088719389731, firstBidPayoff: 0.33839999999921133, secondBidPayoff: 14.694899999999887, totalPayoff: 15.033299999999098
#
# First bid: 907, second bid: 967, pFirstBid: 0.004900000000006344, pSecondBid: 0.44618631293339206, firstBidPayoff: 0.45570000000058997, secondBidPayoff: 14.652000000000514, totalPayoff: 15.107700000001104
#
# First bid: 908, second bid: 967, pFirstBid: 0.006399999999999295, pSecondBid: 0.44535024154589564, firstBidPayoff: 0.5887999999999352, secondBidPayoff: 14.602500000000074, totalPayoff: 15.191300000000009
#
# First bid: 909, second bid: 967, pFirstBid: 0.008099999999998886, pSecondBid: 0.4443996370601724, firstBidPayoff: 0.7370999999998986, secondBidPayoff: 14.54639999999952, totalPayoff: 15.28349999999942
#
# First bid: 910, second bid: 967, pFirstBid: 0.009999999999990905, pSecondBid: 0.44333333333332803, firstBidPayoff: 0.8999999999991815, secondBidPayoff: 14.48369999999996, totalPayoff: 15.383699999999141
#
# First bid: 911, second bid: 967, pFirstBid: 0.012100000000003774, pSecondBid: 0.4421500151837421, firstBidPayoff: 1.076900000000336, secondBidPayoff: 14.414400000000565, totalPayoff: 15.491300000000901
#
# First bid: 912, second bid: 967, pFirstBid: 0.014400000000009072, pSecondBid: 0.4408482142857224, firstBidPayoff: 1.2672000000007984, secondBidPayoff: 14.338500000000131, totalPayoff: 15.60570000000093
#
# First bid: 913, second bid: 967, pFirstBid: 0.016899999999992588, pSecondBid: 0.43942630454684206, firstBidPayoff: 1.4702999999993551, secondBidPayoff: 14.256000000000121, totalPayoff: 15.726299999999476
#
# First bid: 914, second bid: 968, pFirstBid: 0.019599999999982742, pSecondBid: 0.4516523867808928, firstBidPayoff: 1.6855999999985158, secondBidPayoff: 14.169599999999843, totalPayoff: 15.855199999998359
#
# First bid: 915, second bid: 968, pFirstBid: 0.022500000000007958, pSecondBid: 0.4500255754475688, firstBidPayoff: 1.9125000000006764, secondBidPayoff: 14.076799999999839, totalPayoff: 15.989300000000515
#
# First bid: 916, second bid: 968, pFirstBid: 0.02560000000001139, pSecondBid: 0.4482758620689822, firstBidPayoff: 2.150400000000957, secondBidPayoff: 13.977600000000356, totalPayoff: 16.128000000001315
#
# First bid: 917, second bid: 968, pFirstBid: 0.028899999999993042, pSecondBid: 0.4464009885696498, firstBidPayoff: 2.3986999999994225, secondBidPayoff: 13.871999999999682, totalPayoff: 16.270699999999103
#
# First bid: 918, second bid: 968, pFirstBid: 0.032399999999995543, pSecondBid: 0.4443985117817135, firstBidPayoff: 2.6567999999996346, secondBidPayoff: 13.759999999999616, totalPayoff: 16.41679999999925
#
# First bid: 919, second bid: 968, pFirstBid: 0.036100000000018895, pSecondBid: 0.4422657952069926, firstBidPayoff: 2.9241000000015305, secondBidPayoff: 13.641600000000379, totalPayoff: 16.56570000000191
#
# First bid: 920, second bid: 969, pFirstBid: 0.04000000000000625, pSecondBid: 0.4542708333333394, firstBidPayoff: 3.2000000000005002, secondBidPayoff: 13.519100000000092, totalPayoff: 16.719100000000594
#
# First bid: 921, second bid: 969, pFirstBid: 0.04410000000000025, pSecondBid: 0.4519301182132267, firstBidPayoff: 3.4839000000000198, secondBidPayoff: 13.392000000000722, totalPayoff: 16.87590000000074
#
# First bid: 922, second bid: 969, pFirstBid: 0.048399999999986676, pSecondBid: 0.44945355191255487, firstBidPayoff: 3.7751999999989607, secondBidPayoff: 13.25869999999979, totalPayoff: 17.033899999998752
#
# First bid: 923, second bid: 969, pFirstBid: 0.05290000000000816, pSecondBid: 0.4468377151303855, firstBidPayoff: 4.0733000000006285, secondBidPayoff: 13.119199999999518, totalPayoff: 17.192500000000145
#
# First bid: 924, second bid: 969, pFirstBid: 0.05760000000000787, pSecondBid: 0.4440789473684106, firstBidPayoff: 4.377600000000598, secondBidPayoff: 12.973499999999586, totalPayoff: 17.351100000000184
#
# First bid: 925, second bid: 970, pFirstBid: 0.0625, pSecondBid: 0.45599999999998886, firstBidPayoff: 4.6875, secondBidPayoff: 12.824999999999687, totalPayoff: 17.512499999999687
#
# First bid: 926, second bid: 970, pFirstBid: 0.06759999999999877, pSecondBid: 0.4530244530244687, firstBidPayoff: 5.002399999999909, secondBidPayoff: 12.672000000000455, totalPayoff: 17.674400000000364
#
# First bid: 927, second bid: 970, pFirstBid: 0.07289999999998997, pSecondBid: 0.4498975299320307, firstBidPayoff: 5.321699999999268, secondBidPayoff: 12.512999999999705, totalPayoff: 17.834699999998975
#
# First bid: 928, second bid: 970, pFirstBid: 0.07840000000000202, pSecondBid: 0.446614583333357, firstBidPayoff: 5.644800000000146, secondBidPayoff: 12.348000000000628, totalPayoff: 17.992800000000774
#
# First bid: 929, second bid: 971, pFirstBid: 0.0841000000000065, pSecondBid: 0.45856534556175177, firstBidPayoff: 5.971100000000462, secondBidPayoff: 12.180000000000158, totalPayoff: 18.151100000000618
#
# First bid: 930, second bid: 971, pFirstBid: 0.0899999999999892, pSecondBid: 0.4550549450549397, firstBidPayoff: 6.299999999999244, secondBidPayoff: 12.0089, totalPayoff: 18.308899999999245
#
# First bid: 931, second bid: 971, pFirstBid: 0.09609999999999275, pSecondBid: 0.45137736475273016, firstBidPayoff: 6.6308999999994995, secondBidPayoff: 11.831999999999885, totalPayoff: 18.462899999999387
#
# First bid: 932, second bid: 971, pFirstBid: 0.10240000000000293, pSecondBid: 0.44752673796793374, firstBidPayoff: 6.9632000000001995, secondBidPayoff: 11.649300000000464, totalPayoff: 18.612500000000665
#
# First bid: 933, second bid: 972, pFirstBid: 0.10890000000000555, pSecondBid: 0.4595443833464259, firstBidPayoff: 7.296300000000372, secondBidPayoff: 11.465999999999932, totalPayoff: 18.7623000000003
#
# First bid: 934, second bid: 972, pFirstBid: 0.11560000000000059, pSecondBid: 0.4554500226142011, firstBidPayoff: 7.629600000000039, secondBidPayoff: 11.278399999999976, totalPayoff: 18.908000000000015
#
# First bid: 935, second bid: 972, pFirstBid: 0.12249999999998806, pSecondBid: 0.45116809116808554, firstBidPayoff: 7.962499999999224, secondBidPayoff: 11.085200000000013, totalPayoff: 19.04769999999924
#
# First bid: 936, second bid: 973, pFirstBid: 0.1296000000000106, pSecondBid: 0.4633501838235503, firstBidPayoff: 8.294400000000678, secondBidPayoff: 10.889100000000358, totalPayoff: 19.183500000001036
#
# First bid: 937, second bid: 973, pFirstBid: 0.13689999999999714, pSecondBid: 0.4588112617309861, firstBidPayoff: 8.62469999999982, secondBidPayoff: 10.692000000000416, totalPayoff: 19.316700000000235
#
# First bid: 938, second bid: 973, pFirstBid: 0.14439999999999031, pSecondBid: 0.454067321178087, firstBidPayoff: 8.9527999999994, secondBidPayoff: 10.489499999999342, totalPayoff: 19.442299999998742
#
# First bid: 939, second bid: 974, pFirstBid: 0.15209999999999013, pSecondBid: 0.4664465149192125, firstBidPayoff: 9.278099999999398, secondBidPayoff: 10.283000000000127, totalPayoff: 19.561099999999527
#
# First bid: 940, second bid: 974, pFirstBid: 0.1600000000000108, pSecondBid: 0.46142857142855576, firstBidPayoff: 9.600000000000648, secondBidPayoff: 10.077599999999528, totalPayoff: 19.677600000000176
#
# First bid: 941, second bid: 974, pFirstBid: 0.16810000000000969, pSecondBid: 0.45618463757662653, firstBidPayoff: 9.917900000000571, secondBidPayoff: 9.866999999999772, totalPayoff: 19.78490000000034
#
# First bid: 942, second bid: 975, pFirstBid: 0.176400000000001, pSecondBid: 0.4687955318115655, firstBidPayoff: 10.231200000000058, secondBidPayoff: 9.652500000000122, totalPayoff: 19.883700000000182
#
# First bid: 943, second bid: 975, pFirstBid: 0.18489999999998474, pSecondBid: 0.46325604220339756, firstBidPayoff: 10.53929999999913, secondBidPayoff: 9.43999999999991, totalPayoff: 19.979299999999043
#
# First bid: 944, second bid: 975, pFirstBid: 0.19360000000001776, pSecondBid: 0.4574652777777999, firstBidPayoff: 10.841600000000994, secondBidPayoff: 9.222500000000242, totalPayoff: 20.064100000001236
#
# First bid: 945, second bid: 976, pFirstBid: 0.20250000000000057, pSecondBid: 0.4703448275862172, firstBidPayoff: 11.137500000000031, secondBidPayoff: 9.002400000000192, totalPayoff: 20.139900000000225
#
# First bid: 946, second bid: 976, pFirstBid: 0.21160000000000423, pSecondBid: 0.46423135464232246, firstBidPayoff: 11.426400000000228, secondBidPayoff: 8.784000000000121, totalPayoff: 20.210400000000348
#
# First bid: 947, second bid: 976, pFirstBid: 0.2208999999999861, pSecondBid: 0.4578359645744996, firstBidPayoff: 11.707699999999264, secondBidPayoff: 8.560799999999976, totalPayoff: 20.26849999999924
#
# First bid: 948, second bid: 977, pFirstBid: 0.23040000000001726, pSecondBid: 0.47102390852391807, firstBidPayoff: 11.980800000000897, secondBidPayoff: 8.337499999999983, totalPayoff: 20.31830000000088
#
# First bid: 949, second bid: 977, pFirstBid: 0.24010000000001241, pSecondBid: 0.4642716146861403, firstBidPayoff: 12.245100000000633, secondBidPayoff: 8.114399999999822, totalPayoff: 20.359500000000455
#
# First bid: 950, second bid: 977, pFirstBid: 0.25, pSecondBid: 0.4572000000000145, firstBidPayoff: 12.5, secondBidPayoff: 7.88670000000025, totalPayoff: 20.38670000000025
#
# First bid: 951, second bid: 978, pFirstBid: 0.2600999999999942, pSecondBid: 0.4707392890931459, firstBidPayoff: 12.744899999999717, secondBidPayoff: 7.66260000000047, totalPayoff: 20.407500000000187
#
# First bid: 952, second bid: 978, pFirstBid: 0.2703999999999809, pSecondBid: 0.4632675438596152, firstBidPayoff: 12.979199999999082, secondBidPayoff: 7.435999999999651, totalPayoff: 20.415199999998734
#
# First bid: 953, second bid: 979, pFirstBid: 0.2809000000000026, pSecondBid: 0.4772632457237904, firstBidPayoff: 13.202300000000122, secondBidPayoff: 7.207199999999506, totalPayoff: 20.40949999999963
#
# First bid: 954, second bid: 979, pFirstBid: 0.2916000000000025, pSecondBid: 0.46936758893281194, firstBidPayoff: 13.413600000000116, secondBidPayoff: 6.9825000000000585, totalPayoff: 20.396100000000175
#
# First bid: 955, second bid: 979, pFirstBid: 0.3024999999999949, pSecondBid: 0.46107526881718286, firstBidPayoff: 13.61249999999977, secondBidPayoff: 6.753599999999736, totalPayoff: 20.366099999999506
#
# First bid: 956, second bid: 980, pFirstBid: 0.3135999999999939, pSecondBid: 0.4755244755244803, firstBidPayoff: 13.79839999999973, secondBidPayoff: 6.528000000000124, totalPayoff: 20.326399999999854
#
# First bid: 957, second bid: 980, pFirstBid: 0.32490000000001373, pSecondBid: 0.46674566730857237, firstBidPayoff: 13.97070000000059, secondBidPayoff: 6.302000000000215, totalPayoff: 20.272700000000807
#
# First bid: 958, second bid: 981, pFirstBid: 0.3363999999999976, pSecondBid: 0.4817661241712017, firstBidPayoff: 14.128799999999899, secondBidPayoff: 6.074300000000202, totalPayoff: 20.2031000000001
#
# First bid: 959, second bid: 981, pFirstBid: 0.3481000000000023, pSecondBid: 0.4724651020095223, firstBidPayoff: 14.272100000000094, secondBidPayoff: 5.852000000000124, totalPayoff: 20.12410000000022
#
# First bid: 960, second bid: 981, pFirstBid: 0.3599999999999852, pSecondBid: 0.4626562500000375, firstBidPayoff: 14.399999999999409, secondBidPayoff: 5.625900000000586, totalPayoff: 20.025899999999993
#
# First bid: 961, second bid: 982, pFirstBid: 0.3721000000000032, pSecondBid: 0.47826086956524705, firstBidPayoff: 14.511900000000125, secondBidPayoff: 5.4054000000003075, totalPayoff: 19.91730000000043
#
# First bid: 962, second bid: 982, pFirstBid: 0.3843999999999994, pSecondBid: 0.4678362573099264, firstBidPayoff: 14.607199999999978, secondBidPayoff: 5.183999999999838, totalPayoff: 19.791199999999815
#
# First bid: 963, second bid: 983, pFirstBid: 0.39690000000000225, pSecondBid: 0.484165146741816, firstBidPayoff: 14.685300000000083, secondBidPayoff: 4.963999999999798, totalPayoff: 19.649299999999883
#
# First bid: 964, second bid: 983, pFirstBid: 0.4095999999999833, pSecondBid: 0.47306910569102456, firstBidPayoff: 14.7455999999994, secondBidPayoff: 4.74809999999981, totalPayoff: 19.493699999999208
#
# First bid: 965, second bid: 984, pFirstBid: 0.42250000000001364, pSecondBid: 0.490216450216451, firstBidPayoff: 14.787500000000477, secondBidPayoff: 4.5295999999999, totalPayoff: 19.317100000000377
#
# First bid: 966, second bid: 984, pFirstBid: 0.435600000000008, pSecondBid: 0.47838412473421954, firstBidPayoff: 14.810400000000271, secondBidPayoff: 4.319999999999835, totalPayoff: 19.130400000000108
#
# First bid: 967, second bid: 984, pFirstBid: 0.44889999999999475, pSecondBid: 0.4657956813645683, firstBidPayoff: 14.813699999999827, secondBidPayoff: 4.107200000000256, totalPayoff: 18.92090000000008
#
# First bid: 968, second bid: 985, pFirstBid: 0.46239999999998815, pSecondBid: 0.483816964285694, firstBidPayoff: 14.796799999999621, secondBidPayoff: 3.9014999999999223, totalPayoff: 18.69829999999954
#
# First bid: 969, second bid: 985, pFirstBid: 0.4761000000000166, pSecondBid: 0.4703187631227479, firstBidPayoff: 14.759100000000515, secondBidPayoff: 3.695999999999997, totalPayoff: 18.455100000000513
#
# First bid: 970, second bid: 986, pFirstBid: 0.4900000000000091, pSecondBid: 0.4894117647059204, firstBidPayoff: 14.700000000000273, secondBidPayoff: 3.4944000000002093, totalPayoff: 18.19440000000048
#
# First bid: 971, second bid: 986, pFirstBid: 0.504099999999994, pSecondBid: 0.4748941318814275, firstBidPayoff: 14.618899999999826, secondBidPayoff: 3.2970000000000383, totalPayoff: 17.915899999999866
#
# First bid: 972, second bid: 987, pFirstBid: 0.5183999999999855, pSecondBid: 0.4952242524916528, firstBidPayoff: 14.515199999999595, secondBidPayoff: 3.100499999999833, totalPayoff: 17.61569999999943
#
# First bid: 973, second bid: 987, pFirstBid: 0.5329000000000121, pSecondBid: 0.4795546992078812, firstBidPayoff: 14.388300000000328, secondBidPayoff: 2.9119999999999413, totalPayoff: 17.30030000000027
#
# First bid: 974, second bid: 988, pFirstBid: 0.5476000000000028, pSecondBid: 0.5013262599469499, firstBidPayoff: 14.237600000000072, secondBidPayoff: 2.721599999999985, totalPayoff: 16.959200000000056
#
# First bid: 975, second bid: 988, pFirstBid: 0.5625, pSecondBid: 0.4843428571428774, firstBidPayoff: 14.0625, secondBidPayoff: 2.5428000000001063, totalPayoff: 16.605300000000106
#
# First bid: 976, second bid: 988, pFirstBid: 0.5775999999999897, pSecondBid: 0.46590909090903665, firstBidPayoff: 13.862399999999752, secondBidPayoff: 2.3615999999997825, totalPayoff: 16.223999999999535
#
# First bid: 977, second bid: 989, pFirstBid: 0.592899999999986, pSecondBid: 0.4893146647015101, firstBidPayoff: 13.636699999999678, secondBidPayoff: 2.191199999999908, totalPayoff: 15.827899999999586
#
# First bid: 978, second bid: 989, pFirstBid: 0.6084000000000032, pSecondBid: 0.46910112359549316, firstBidPayoff: 13.38480000000007, secondBidPayoff: 2.02069999999993, totalPayoff: 15.4055
#
# First bid: 979, second bid: 990, pFirstBid: 0.6240999999999985, pSecondBid: 0.49454642192074516, firstBidPayoff: 13.10609999999997, secondBidPayoff: 1.8590000000000884, totalPayoff: 14.965100000000058
#
# First bid: 980, second bid: 990, pFirstBid: 0.6400000000000006, pSecondBid: 0.47222222222222854, firstBidPayoff: 12.800000000000011, secondBidPayoff: 1.7000000000000202, totalPayoff: 14.500000000000032
#
# First bid: 981, second bid: 991, pFirstBid: 0.6560999999999808, pSecondBid: 0.5001453911021372, firstBidPayoff: 12.465899999999635, secondBidPayoff: 1.5480000000003111, totalPayoff: 14.013899999999946
#
# First bid: 982, second bid: 991, pFirstBid: 0.6724000000000103, pSecondBid: 0.47527472527468717, firstBidPayoff: 12.103200000000186, secondBidPayoff: 1.4012999999998434, totalPayoff: 13.504500000000029
#
# First bid: 983, second bid: 992, pFirstBid: 0.6889000000000038, pSecondBid: 0.506268081002986, firstBidPayoff: 11.711300000000065, secondBidPayoff: 1.260000000000216, totalPayoff: 12.971300000000282
#
# First bid: 984, second bid: 992, pFirstBid: 0.7055999999999898, pSecondBid: 0.47826086956513336, firstBidPayoff: 11.289599999999837, secondBidPayoff: 1.126399999999841, totalPayoff: 12.415999999999677
#
# First bid: 985, second bid: 993, pFirstBid: 0.7224999999999824, pSecondBid: 0.5131531531530413, firstBidPayoff: 10.837499999999736, secondBidPayoff: 0.996799999999846, totalPayoff: 11.834299999999581
#
# First bid: 986, second bid: 993, pFirstBid: 0.73960000000001, pSecondBid: 0.4811827956989987, firstBidPayoff: 10.35440000000014, secondBidPayoff: 0.877100000000101, totalPayoff: 11.231500000000242
#
# First bid: 987, second bid: 994, pFirstBid: 0.7569000000000017, pSecondBid: 0.5211846976553147, firstBidPayoff: 9.839700000000022, secondBidPayoff: 0.7602000000000368, totalPayoff: 10.599900000000058
#
# First bid: 988, second bid: 994, pFirstBid: 0.7744, pSecondBid: 0.4840425531914434, firstBidPayoff: 9.2928, secondBidPayoff: 0.6551999999999378, totalPayoff: 9.947999999999938
#
# First bid: 989, second bid: 995, pFirstBid: 0.7920999999999907, pSecondBid: 0.5310245310245705, firstBidPayoff: 8.713099999999898, secondBidPayoff: 0.5520000000000657, totalPayoff: 9.265099999999963
#
# First bid: 990, second bid: 995, pFirstBid: 0.8100000000000165, pSecondBid: 0.4868421052632357, firstBidPayoff: 8.100000000000165, secondBidPayoff: 0.4625000000000338, totalPayoff: 8.562500000000199
#
# First bid: 991, second bid: 996, pFirstBid: 0.8281000000000063, pSecondBid: 0.5439208842351491, firstBidPayoff: 7.4529000000000565, secondBidPayoff: 0.37400000000007483, totalPayoff: 7.826900000000132
#
# First bid: 992, second bid: 996, pFirstBid: 0.8464000000000027, pSecondBid: 0.48958333333337123, firstBidPayoff: 6.771200000000022, secondBidPayoff: 0.300800000000018, totalPayoff: 7.07200000000004
#
# First bid: 993, second bid: 997, pFirstBid: 0.8648999999999916, pSecondBid: 0.5625462620279222, firstBidPayoff: 6.054299999999941, secondBidPayoff: 0.22799999999993112, totalPayoff: 6.282299999999872
#
# First bid: 994, second bid: 997, pFirstBid: 0.8836000000000155, pSecondBid: 0.49226804123736656, firstBidPayoff: 5.301600000000093, secondBidPayoff: 0.17190000000006553, totalPayoff: 5.473500000000159
#
# First bid: 995, second bid: 998, pFirstBid: 0.9025000000000034, pSecondBid: 0.5938461538462434, firstBidPayoff: 4.512500000000017, secondBidPayoff: 0.1158000000000134, totalPayoff: 4.6283000000000305
#
# First bid: 996, second bid: 998, pFirstBid: 0.921599999999998, pSecondBid: 0.49489795918384516, firstBidPayoff: 3.686399999999992, secondBidPayoff: 0.07760000000002892, totalPayoff: 3.7640000000000207
#
# First bid: 997, second bid: 999, pFirstBid: 0.940899999999985, pSecondBid: 0.6632825719120774, firstBidPayoff: 2.822699999999955, secondBidPayoff: 0.039200000000013745, totalPayoff: 2.861899999999969
#
# First bid: 998, second bid: 999, pFirstBid: 0.960400000000007, pSecondBid: 0.4974747474743708, firstBidPayoff: 1.920800000000014, secondBidPayoff: 0.01969999999998159, totalPayoff: 1.9404999999999957
#
# First bid: 999, second bid: 999, pFirstBid: 0.9801000000000073, pSecondBid: 0.0, firstBidPayoff: 0.9801000000000073, secondBidPayoff: 0.0, totalPayoff: 0.9801000000000073
